# %% [markdown]
# # Import used modules

# %%
import pandas as pd
import sys
sys.path.insert(0, '../src')
import benchmark_utils as bu
import analysis_utils as au
# Out:
# /Users/julian/opt/anaconda3/envs/OpenCADDBenchmark/lib/python3.8/site-packages/MDAnalysis/coordinates/chemfiles.py:108: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   MIN_CHEMFILES_VERSION = LooseVersion("0.9")

# %% [markdown]
# # Run Alignments for OpenCADD.superposition for the TK and CAMK Structures

# %% [markdown]
# Perform all pairwise alignments for the given sample structures. Every method performs 2500 alignments for the 50 tyrosine kinase and 50 CAMK structures. The benchmark is done with an Intel Core i5-1038NG7 CPU and 16 GB of RAM.

# %%
#bu.run_alignments(sample1_path="/Users/julian/PythonProjects/Bachelor/benchmark/TK_samples.txt", 
#                  sample2_path="/Users/julian/PythonProjects/Bachelor/benchmark/CAMK_samples.txt", 
#                  output_path="../data/OpenCADD_results/<NAME_OF_FILE>")

# %% [markdown]
# # Create a Dataframe containing the Alignments of all five Methods

# %% [markdown]
# The alignments for PyMol and ChimeraX MatchMaker are done in the respectively programs and are saved in seperate files. For the analysis, the DataFrames are combined.

# %%
columns = ["reference_id", "mobile_id", "method", "rmsd", 
           "coverage", "reference_size", "mobile_size", "time", 
           "SI", "MI", "SAS", "ref_name", "ref_group", "ref_species", 
           "ref_chain", "mob_name", "mob_group", "mob_species", "mob_chain"]
superposer_TK_CAMK = pd.read_csv("../data/OpenCADD_results/superposer_benchmark_TK_CAMK.csv", names=columns)
pymol_TK_CAMK = pd.read_csv("../data/PyMol_results/pymol_benchmark_TK_CAMK.csv", names=columns)
chimerax_TK_CAMK = pd.read_csv("../data/ChimeraX_results/mmaker_benchmark_TK_CAMK.csv", names=columns)
all_TK_CAMK = pd.concat([superposer_TK_CAMK, pymol_TK_CAMK, chimerax_TK_CAMK]).reset_index(drop=True)

# %% [markdown]
# ### Compute the relative Coverage

# %% [markdown]
# The relative coverage is computed the following way:
#
# coverage / min(lenght of structure 1, lenght of structure 2)

# %%
au.compute_rel_cov(all_TK_CAMK)

# %% [markdown]
# # Analysis

# %% [markdown]
# ## General Checks

# %%
counts, nans, times = au.general_checks(all_TK_CAMK)

# %% [markdown]
# Check if every value is present.
# It should be 2500 for every value, because there are 2500 alignments performed per method.

# %%
counts
# Out:
#             reference_id  mobile_id  rmsd  coverage  reference_size  \
# method
# matchmaker          2500       2500  2500      2500            2500
# mda                 2500       2500  2500      2500            2500
# mmligner            2500       2500  2498      2498            2498
# pymol               2500       2500  2500      2500            2500
# theseus             2500       2500  2500      2500            2500
#
#             mobile_size  time    SI    MI   SAS  ref_name  ref_group  \
# method
# matchmaker         2500  2500  2500  2500  2500      2500       2500
# mda                2500  2500  2500  2500  2500      2500       2500
# mmligner           2498  2498  2498  2498  2498      2500       2500
# pymol              2500  2500  2500  2500  2500      2500       2500
# theseus            2500  2500  2500  2500  2500      2500       2500
#
#             ref_species  ref_chain  mob_name  mob_group  mob_species  \
# method
# matchmaker         2500       2500      2500       2500         2500
# mda                2500       2500      2500       2500         2500
# mmligner           2500       2500      2500       2500         2500
# pymol              2500       2500      2500       2500         2500
# theseus            2500       2500      2500       2500         2500
#
#             mob_chain  rel_cov
# method
# matchmaker       2500     2500
# mda              2500     2500
# mmligner         2500     2498
# pymol            2500     2500
# theseus          2500     2500

# %% [markdown]
# Next, we check for missing alignments. Some Methods have problems with some structures.
#
# In this case, all alignments worked except two for MMLigner with the structure 5hhw.
# These two entries are removed for further analysis.

# %%
nans
# Out:
#           reference_id  mobile_id  rmsd  coverage  reference_size  \
# method
# mmligner             2          2     0         0               0
#
#           mobile_size  time  SI  MI  SAS  ref_name  ref_group  ref_species  \
# method
# mmligner            0     0   0   0    0         2          2            2
#
#           ref_chain  mob_name  mob_group  mob_species  mob_chain  rel_cov
# method
# mmligner          2         2          2            2          2        0

# %%
all_TK_CAMK[all_TK_CAMK["rmsd"].isna()]
# Out:
#      reference_id mobile_id    method  rmsd  coverage  reference_size  \
# 3921         5hhw      6vru  mmligner   NaN       NaN             NaN
# 3922         5hhw      4wsy  mmligner   NaN       NaN             NaN
#
#       mobile_size  time  SI  MI  SAS ref_name ref_group ref_species ref_chain  \
# 3921          NaN   NaN NaN NaN  NaN     INSR        TK       Human         A
# 3922          NaN   NaN NaN NaN  NaN     INSR        TK       Human         A
#
#      mob_name mob_group mob_species mob_chain  rel_cov
# 3921     PIM1      CAMK       Human         A      NaN
# 3922     PIM1      CAMK       Human         A      NaN

# %%
all_TK_CAMK = all_TK_CAMK.dropna()

# %% [markdown]
# During the computation of the alignments, the time is measured.  For all OpenCADD methods combined the CPU-time is just under 12.5 hours. The time for downloading the structures is not included.
# PyMol align took less than a minute.

# %%
times
# Out:
# method
# matchmaker     17.41
# mda            18.29
# mmligner      715.80
# pymol           0.86
# theseus        14.08
# Name: time, dtype: float64

# %% [markdown]
# ### Compute Mean and Median

# %%
mean, median = au.compute_mean_median(all_TK_CAMK)

# %%
mean
# Out:
#               rmsd  coverage  reference_size  mobile_size     time       SI  \
# method
# matchmaker  6.3234  245.8000        284.7200     281.2000   0.4178   7.0252
# mda         9.0286  247.2692        284.2800     281.1200   0.4390   9.9810
# mmligner    2.3544  218.2686        284.2626     281.1265  17.1929   2.9335
# pymol       7.4921  204.8832        284.7200     281.2000   0.0206  10.0365
# theseus     9.5277  247.3240        284.2800     281.1200   0.3379  10.5295
#
#                 MI     SAS  rel_cov
# method
# matchmaker  0.8142  2.5703   0.9035
# mda         0.8612  3.6592   0.9091
# mmligner    0.6857  1.0778   0.8029
# pymol       0.8649  3.6844   0.7532
# theseus     0.8666  3.8591   0.9093

# %%
median
# Out:
#               rmsd  coverage  reference_size  mobile_size     time       SI  \
# method
# matchmaker  5.7500     246.0           280.0        274.0   0.3803   6.3358
# mda         8.9708     247.0           280.0        274.0   0.4216   9.8174
# mmligner    2.3970     220.0           280.0        274.0  16.9158   2.8944
# pymol       7.3306     208.0           280.0        274.0   0.0198   9.6175
# theseus     9.4578     248.0           280.0        274.0   0.2928  10.4200
#
#                 MI     SAS  rel_cov
# method
# matchmaker  0.8122  2.3465   0.9071
# mda         0.8691  3.6640   0.9108
# mmligner    0.6832  1.0663   0.8067
# pymol       0.8704  3.5625   0.7622
# theseus     0.8755  3.8742   0.9108

# %% [markdown]
# ## Create basic plots

# %% [markdown]
# It is easy to see in both plots, that MMLigner performs the best. Besides that, Theseus performs very similar to ChimeraX MatchMaker and PyMol align.

# %%
au.create_scatter_plot(all_TK_CAMK, path="../reports/figures/TK_CAMK")
au.create_violine_plot(all_TK_CAMK, path="../reports/figures/TK_CAMK")

# %% [markdown]
# ## Check if data is normally distributed

# %% [markdown]
# The Kolmogorov-Smirnow-Test shows, that the values for RMSD, SI, MI, SAS and relative coverage are not normally distributed. But Theseus has a very similar distribution for the measures except the relative coverage. MMLigner performs the best for all measures except the relative coverage. MDA performs the worst for all measures.

# %%
dist_tests = au.check_distribution(all_TK_CAMK, path="../reports/figures/TK_CAMK")
# Out:
# Results of kstest:
# KstestResult(statistic=0.9476356803720634, pvalue=0.0)
# KstestResult(statistic=0.9820501713890728, pvalue=0.0)
# KstestResult(statistic=0.734590141645466, pvalue=0.0)
# KstestResult(statistic=0.7982968665228324, pvalue=0.0)

# %% [markdown]
# ## Compute Correlation

# %% [markdown]
# Since the data is not distributed normally, the spearman correlation is used.
#
# The three quality measures correlate very well with each other and with the rmsd. The quality measures also negatively correlate with the relative coverage, which means, the lower the relative coverage, the higher the quality measures.
#
# The time also negatively correlates with the quality measures, which means taking more time for an alignment produces better results. This correlation in this case is highly biased by MMLigner. It takes much more time than the other methods, but also yield overall the best results.
#
# All three quality measures share the property, that lower values mean better alignments.

# %%
corr = au.compute_correlation(all_TK_CAMK, coeff="spearman", path="../reports/figures/TK_CAMK")
corr
# Out:
#                     rmsd  coverage  reference_size  mobile_size      time  \
# rmsd            1.000000  0.352402        0.132644     0.096548 -0.434550
# coverage        0.352402  1.000000        0.192144     0.222092  0.151446
# reference_size  0.132644  0.192144        1.000000     0.000343  0.053703
# mobile_size     0.096548  0.222092        0.000343     1.000000  0.123958
# time           -0.434550  0.151446        0.053703     0.123958  1.000000
# SI              0.977759  0.202398        0.143742     0.110425 -0.515708
# MI              0.967632  0.166852        0.147256     0.111519 -0.529819
# SAS             0.976836  0.179148        0.103406     0.063740 -0.525883
# rel_cov         0.276437  0.860999       -0.059795    -0.062238  0.100506
#
#                       SI        MI       SAS   rel_cov
# rmsd            0.977759  0.967632  0.976836  0.276437
# coverage        0.202398  0.166852  0.179148  0.860999
# reference_size  0.143742  0.147256  0.103406 -0.059795
# mobile_size     0.110425  0.111519  0.063740 -0.062238
# time           -0.515708 -0.529819 -0.525883  0.100506
# SI              1.000000  0.998494  0.996512  0.109000
# MI              0.998494  1.000000  0.994319  0.069187
# SAS             0.996512  0.994319  1.000000  0.122361
# rel_cov         0.109000  0.069187  0.122361  1.000000

# %% [markdown]
# ## Check for significant differences

# %% [markdown]
# Because the data is not normally distributed, an ANOVA is not suitable. Therefore the Kruskal-Wallis-Test is performed. The RMSD and the three quality measures are significantly different for the groups.

# %%
kruskal = au.compute_kruskal(all_TK_CAMK)
# Out:
# Kruskal Wallis results for RMSD:
# KruskalResult(statistic=7335.782264042279, pvalue=0.0)
#
#
# Kruskal Wallis results for Similarity Index (SI):
# KruskalResult(statistic=7194.708562493128, pvalue=0.0)
#
#
# Kruskal Wallis results for Match Index (MI):
# KruskalResult(statistic=7212.511383385292, pvalue=0.0)
#
#
# Kruskal Wallis results for Structural Alignment Score (SAS):
# KruskalResult(statistic=7253.757296120138, pvalue=0.0)

# %% [markdown]
# ## Which groups are different

# %% [markdown]
# The statistics show, that all groups are significantly different from each other. Looking at the diagrams above it is still noticable, that PyMol, ChimeraX and Theseus are in the same area, but Theseus performs the worst out of the three.

# %%
significant, non_significant = au.compute_mannwhitneyu(all_TK_CAMK)
# Out:
# All significant results:
# Result for rmsd with theseus and pymol:
# MannwhitneyuResult(statistic=4393745.5, pvalue=2.029229446426067e-136)
# Result for rmsd with theseus and mmaker:
# MannwhitneyuResult(statistic=5106922.0, pvalue=0.0)
# Result for rmsd with theseus and mmligner:
# MannwhitneyuResult(statistic=6245000.0, pvalue=0.0)
# Result for rmsd with theseus and mda:
# MannwhitneyuResult(statistic=3426463.0, pvalue=3.48724193669097e-09)
# Result for rmsd with pymol and mmaker:
# MannwhitneyuResult(statistic=4071419.0, pvalue=9.103630215043421e-77)
# Result for rmsd with pymol and mmligner:
# MannwhitneyuResult(statistic=6242672.0, pvalue=0.0)
# Result for rmsd with pymol and mda:
# MannwhitneyuResult(statistic=2088298.0, pvalue=9.85150899777665e-92)
# Result for rmsd with mmaker and mmligner:
# MannwhitneyuResult(statistic=6243514.0, pvalue=0.0)
# Result for rmsd with mmaker and mda:
# MannwhitneyuResult(statistic=1293329.0, pvalue=4.426184813888311e-282)
# Result for rmsd with mmligner and mda:
# MannwhitneyuResult(statistic=0.0, pvalue=0.0)
# Result for SI with theseus and pymol:
# MannwhitneyuResult(statistic=4393745.5, pvalue=2.029229446426067e-136)
# Result for SI with theseus and mmaker:
# MannwhitneyuResult(statistic=5106922.0, pvalue=0.0)
# Result for SI with theseus and mmligner:
# MannwhitneyuResult(statistic=6245000.0, pvalue=0.0)
# Result for SI with theseus and mda:
# MannwhitneyuResult(statistic=3426463.0, pvalue=3.48724193669097e-09)
# Result for SI with pymol and mmaker:
# MannwhitneyuResult(statistic=4071419.0, pvalue=9.103630215043421e-77)
# Result for SI with pymol and mmligner:
# MannwhitneyuResult(statistic=6242672.0, pvalue=0.0)
# Result for SI with pymol and mda:
# MannwhitneyuResult(statistic=2088298.0, pvalue=9.85150899777665e-92)
# Result for SI with mmaker and mmligner:
# MannwhitneyuResult(statistic=6243514.0, pvalue=0.0)
# Result for SI with mmaker and mda:
# MannwhitneyuResult(statistic=1293329.0, pvalue=4.426184813888311e-282)
# Result for SI with mmligner and mda:
# MannwhitneyuResult(statistic=0.0, pvalue=0.0)
# Result for MI with theseus and pymol:
# MannwhitneyuResult(statistic=4393745.5, pvalue=2.029229446426067e-136)
# Result for MI with theseus and mmaker:
# MannwhitneyuResult(statistic=5106922.0, pvalue=0.0)
# Result for MI with theseus and mmligner:
# MannwhitneyuResult(statistic=6245000.0, pvalue=0.0)
# Result for MI with theseus and mda:
# MannwhitneyuResult(statistic=3426463.0, pvalue=3.48724193669097e-09)
# Result for MI with pymol and mmaker:
# MannwhitneyuResult(statistic=4071419.0, pvalue=9.103630215043421e-77)
# Result for MI with pymol and mmligner:
# MannwhitneyuResult(statistic=6242672.0, pvalue=0.0)
# Result for MI with pymol and mda:
# MannwhitneyuResult(statistic=2088298.0, pvalue=9.85150899777665e-92)
# Result for MI with mmaker and mmligner:
# MannwhitneyuResult(statistic=6243514.0, pvalue=0.0)
# Result for MI with mmaker and mda:
# MannwhitneyuResult(statistic=1293329.0, pvalue=4.426184813888311e-282)
# Result for MI with mmligner and mda:
# MannwhitneyuResult(statistic=0.0, pvalue=0.0)
# Result for SAS with theseus and pymol:
# MannwhitneyuResult(statistic=4393745.5, pvalue=2.029229446426067e-136)
# Result for SAS with theseus and mmaker:
# MannwhitneyuResult(statistic=5106922.0, pvalue=0.0)
# Result for SAS with theseus and mmligner:
# MannwhitneyuResult(statistic=6245000.0, pvalue=0.0)
# Result for SAS with theseus and mda:
# MannwhitneyuResult(statistic=3426463.0, pvalue=3.48724193669097e-09)
# Result for SAS with pymol and mmaker:
# MannwhitneyuResult(statistic=4071419.0, pvalue=9.103630215043421e-77)
# Result for SAS with pymol and mmligner:
# MannwhitneyuResult(statistic=6242672.0, pvalue=0.0)
# Result for SAS with pymol and mda:
# MannwhitneyuResult(statistic=2088298.0, pvalue=9.85150899777665e-92)
# Result for SAS with mmaker and mmligner:
# MannwhitneyuResult(statistic=6243514.0, pvalue=0.0)
# Result for SAS with mmaker and mda:
# MannwhitneyuResult(statistic=1293329.0, pvalue=4.426184813888311e-282)
# Result for SAS with mmligner and mda:
# MannwhitneyuResult(statistic=0.0, pvalue=0.0)
#
# ***********************************
#
# All non significant results:

# %% [markdown]
# # Count the best alignments

# %% [markdown]
# For every pair of structures, the method that has the best quality measure is selected. The following statistics show how often a method had the best results for the quality measures.

# %%
best_results = au.count_best_results(all_TK_CAMK)
# Out:
# Counts of best values for the Similarity Index (SI):
# mmligner      2498
# matchmaker       2
# Name: method, dtype: int64
#
#
# Counts of best values for the Match Index (MI):
# mmligner      2498
# matchmaker       2
# Name: method, dtype: int64
#
#
# Counts of best values for the Structural Alignment Score (SAS):
# mmligner      2498
# matchmaker       2
# Name: method, dtype: int64
#
#
# Counts of best values for the Similarity Index (SI) without MMLigner:
# matchmaker    1913
# pymol          336
# mda            250
# theseus          1
# Name: method, dtype: int64
#
#
# Counts of best values for the Match Index (MI) without MMLigner:
# matchmaker    1938
# mda            285
# pymol          276
# theseus          1
# Name: method, dtype: int64
#
#
# Counts of best values for the Structural Alignment Score (SAS) without MMLigner:
# matchmaker    1914
# pymol          336
# mda            249
# theseus          1
# Name: method, dtype: int64
